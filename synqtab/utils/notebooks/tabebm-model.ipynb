# %%
# !git clone https://github.com/Gatmatz/SynQTab.git
# %cd SynQTab
# !rm ./.env
# !bash scripts/prepare-execution-environment-tabebm.sh

# %%
with open("./.env", "w") as f:
  f.write("""
MINIO_ROOT_USER='dq_user'
MINIO_ROOT_PASSWORD='dq_password'
MINIO_API_MAPPED_PORT=9000
MINIO_UI_MAPPED_PORT=9001
MINIO_HOST='panther.csd.auth.gr'

POSTGRES_USER='dq_user'
POSTGRES_PASSWORD='dq_password'
POSTGRES_MAPPED_PORT=5342
POSTGRES_HOST='cobra.csd.auth.gr'
POSTGRES_DB='synqtab'

ADMINER_MAPPED_PORT=9001

RANDOM_SEEDS='16840, 190459, 318736'
POLLUTION_RATES='0.1, 0.2, 0.4'
MAX_TRAINING_ROWS=10000

EXECUTION_PROFILE='Kaggle'
DISCORD_WEBHOOK_URL='https://discord.com/api/webhooks/1465326747657699439/4Sq5qbyLVVBKM4HUwmgUO-11ix8Jpd3bqg-Z-TlrK5QQ7qLx7qZCyE6IMUFQHFzS9GJ2'
WANDB_MODE='disabled'
""")

# %%
# !cd synqtab/utils && python run_normal_experiment.py

# %%
import sys
sys.exit(0)
